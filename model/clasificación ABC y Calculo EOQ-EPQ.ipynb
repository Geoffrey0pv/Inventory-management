# %% [markdown]
# # ***Clasificación ABC de SKUS***

# %% [markdown]
# # Organizar Data Base

# %%
import numpy as np
import pandas as pd
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_excel("/content/drive/MyDrive/Operaciones I/Base de datos/Datos Ope1 Team 3 (1).xlsx")

# %%
data
# Out:
#               Tipo   Familias          SKUS  \
# 0   compra y venta  Familia 1         SKU 1
# 1   compra y venta        NaN         SKU 2
# 2   compra y venta        NaN         SKU 3
# 3    Manufacturado  Familia 2         SKU 4
# 4    Manufacturado        NaN         SKU 5
# 5    Manufacturado        NaN         SKU 6
# 6   compra y venta  Familia 3         SKU 7
# 7   compra y venta        NaN         SKU 8
# 8   compra y venta        NaN         SKU 9
# 9    Manufacturado  Familia 4        SKU 10
# 10   Manufacturado        NaN        SKU 11
# 11   Manufacturado        NaN        SKU 12
# 12             NaN        NaN           NaN
# 13             NaN        NaN  Penalización
# 14             NaN        NaN   de faltante
#
#     Cargo de Mantener una unidad en un año          Rentabilidad  \
# 0                                     0.18                  0.18
# 1                                     0.18                  0.25
# 2                                     0.18                  0.22
# 3                                     0.26                  0.26
# 4                                     0.26                  0.25
# 5                                     0.26                   0.3
# 6                                     0.20                  0.15
# 7                                     0.20                  0.21
# 8                                     0.20                  0.25
# 9                                     0.25                  0.28
# 10                                    0.25                   0.3
# 11                                    0.25                  0.22
# 12                                     NaN                   NaN
# 13                                    0.95  factor a multiplicar
# 14                                     NaN                   NaN
#
#     Total Demanda  Promedio semana  Desv. Estándar        Cv  Costo unitario   \
# 0        100571.0      1117.455556      548.693672  0.491021          26478.0
# 1        108196.0      1202.177778      598.309990  0.497688          35621.0
# 2        106396.0      1182.177778      603.645267  0.510621          40218.0
# 3        131526.0      1461.400000      274.140774  0.187588          64570.0
# 4        128338.0      1425.977778      253.785275  0.177973          56478.0
# 5        131255.0      1458.388889      281.232548  0.192838          34867.0
# 6        120159.0      1335.100000      456.989761  0.342289          56416.0
# 7        123184.0      1368.711111      501.595393  0.366473          64179.0
# 8        120719.0      1341.322222      413.133431  0.308005          42351.0
# 9        113177.0      1257.522222      434.914669  0.345850          62415.0
# 10       112246.0      1247.177778      442.127151  0.354502          35468.0
# 11       109188.0      1213.200000      414.435428  0.341605          24690.0
# 12      1404955.0              NaN             NaN       NaN              NaN
# 13            NaN              NaN             NaN       NaN              NaN
# 14            NaN              NaN             NaN       NaN              NaN
#
#     Costo Ordenar  Tasa Pdn (unid por semana)
# 0       3415860.0                         NaN
# 1       5124610.0                         NaN
# 2       2471600.0                         NaN
# 3       3451200.0                      1800.0
# 4       4023600.0                      2000.0
# 5       3845650.0                      1700.0
# 6       6451870.0                         NaN
# 7       4781900.0                         NaN
# 8       2345640.0                         NaN
# 9       7845000.0                      1500.0
# 10      4567180.0                      2200.0
# 11      3654130.0                      2500.0
# 12            NaN                         NaN
# 13            NaN                         NaN
# 14            NaN                         NaN

# %%
data.columns
# Out:
# Index(['Tipo', 'Familias', 'SKUS', 'Cargo de Mantener una unidad en un año',
#        'Rentabilidad', 'Total Demanda', 'Promedio semana', 'Desv. Estándar',
#        'Cv', 'Costo unitario ', 'Costo Ordenar', 'Tasa Pdn (unid por semana)'],
#       dtype='object')

# %%
data = data.drop([12,13,14])

# %%
data.shape
# Out:
# (12, 12)

# %% [markdown]
# # Clasificación ABC - Ventas

# %% [markdown]
# ## Clasificación ABC costo unitario (Demanda x costo)

# %%
dataSubset = data[["SKUS",'Total Demanda','Costo unitario ']]

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario
# 0    SKU 1       100571.0          26478.0
# 1    SKU 2       108196.0          35621.0
# 2    SKU 3       106396.0          40218.0
# 3    SKU 4       131526.0          64570.0
# 4    SKU 5       128338.0          56478.0
# 5    SKU 6       131255.0          34867.0
# 6    SKU 7       120159.0          56416.0
# 7    SKU 8       123184.0          64179.0
# 8    SKU 9       120719.0          42351.0
# 9   SKU 10       113177.0          62415.0
# 10  SKU 11       112246.0          35468.0
# 11  SKU 12       109188.0          24690.0

# %%
dataSubset["Valor Total costos por sku"] = dataSubset["Total Demanda"] * dataSubset['Costo unitario ']
# Out:
# <ipython-input-166-ed143b097362>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSubset["Valor Total costos por sku"] = dataSubset["Total Demanda"] * dataSubset['Costo unitario ']

# %%
dataSubset = dataSubset.sort_values(by='Valor Total costos por sku', ascending=False)

# %%
totalCosts = dataSubset["Valor Total costos por sku"].sum()
totalCosts
# Out:
# 64651600203.0

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario   Valor Total costos por sku
# 3    SKU 4       131526.0          64570.0                8.492634e+09
# 7    SKU 8       123184.0          64179.0                7.905826e+09
# 4    SKU 5       128338.0          56478.0                7.248274e+09
# 9   SKU 10       113177.0          62415.0                7.063942e+09
# 6    SKU 7       120159.0          56416.0                6.778890e+09
# 8    SKU 9       120719.0          42351.0                5.112570e+09
# 5    SKU 6       131255.0          34867.0                4.576468e+09
# 2    SKU 3       106396.0          40218.0                4.279034e+09
# 10  SKU 11       112246.0          35468.0                3.981141e+09
# 1    SKU 2       108196.0          35621.0                3.854050e+09
# 11  SKU 12       109188.0          24690.0                2.695852e+09
# 0    SKU 1       100571.0          26478.0                2.662919e+09

# %%
dataSubset["Costos Acumuludos"] = dataSubset["Valor Total costos por sku"].cumsum()

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario   Valor Total costos por sku  \
# 3    SKU 4       131526.0          64570.0                8.492634e+09
# 7    SKU 8       123184.0          64179.0                7.905826e+09
# 4    SKU 5       128338.0          56478.0                7.248274e+09
# 9   SKU 10       113177.0          62415.0                7.063942e+09
# 6    SKU 7       120159.0          56416.0                6.778890e+09
# 8    SKU 9       120719.0          42351.0                5.112570e+09
# 5    SKU 6       131255.0          34867.0                4.576468e+09
# 2    SKU 3       106396.0          40218.0                4.279034e+09
# 10  SKU 11       112246.0          35468.0                3.981141e+09
# 1    SKU 2       108196.0          35621.0                3.854050e+09
# 11  SKU 12       109188.0          24690.0                2.695852e+09
# 0    SKU 1       100571.0          26478.0                2.662919e+09
#
#     Costos Acumuludos
# 3        8.492634e+09
# 7        1.639846e+10
# 4        2.364673e+10
# 9        3.071068e+10
# 6        3.748957e+10
# 8        4.260214e+10
# 5        4.717860e+10
# 2        5.145764e+10
# 10       5.543878e+10
# 1        5.929283e+10
# 11       6.198868e+10
# 0        6.465160e+10

# %%
dataSubset["Porcentaje de costos acumulados"] = dataSubset['Costos Acumuludos'] / totalCosts

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario   Valor Total costos por sku  \
# 3    SKU 4       131526.0          64570.0                8.492634e+09
# 7    SKU 8       123184.0          64179.0                7.905826e+09
# 4    SKU 5       128338.0          56478.0                7.248274e+09
# 9   SKU 10       113177.0          62415.0                7.063942e+09
# 6    SKU 7       120159.0          56416.0                6.778890e+09
# 8    SKU 9       120719.0          42351.0                5.112570e+09
# 5    SKU 6       131255.0          34867.0                4.576468e+09
# 2    SKU 3       106396.0          40218.0                4.279034e+09
# 10  SKU 11       112246.0          35468.0                3.981141e+09
# 1    SKU 2       108196.0          35621.0                3.854050e+09
# 11  SKU 12       109188.0          24690.0                2.695852e+09
# 0    SKU 1       100571.0          26478.0                2.662919e+09
#
#     Costos Acumuludos  Porcentaje de costos acumulados
# 3        8.492634e+09                         0.131360
# 7        1.639846e+10                         0.253644
# 4        2.364673e+10                         0.365756
# 9        3.071068e+10                         0.475018
# 6        3.748957e+10                         0.579871
# 8        4.260214e+10                         0.658949
# 5        4.717860e+10                         0.729736
# 2        5.145764e+10                         0.795922
# 10       5.543878e+10                         0.857501
# 1        5.929283e+10                         0.917113
# 11       6.198868e+10                         0.958811
# 0        6.465160e+10                         1.000000

# %%
def ABC(cumPer):
    if cumPer >= 0 and cumPer < 0.50:
        return 'A'
    elif cumPer >= 0.50 and cumPer <= 0.90:
        return 'B'
    elif cumPer > 0.90:
        return 'C'

# %%
dataSubset['Class'] = dataSubset['Porcentaje de costos acumulados'].apply(ABC)

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario   Valor Total costos por sku  \
# 3    SKU 4       131526.0          64570.0                8.492634e+09
# 7    SKU 8       123184.0          64179.0                7.905826e+09
# 4    SKU 5       128338.0          56478.0                7.248274e+09
# 9   SKU 10       113177.0          62415.0                7.063942e+09
# 6    SKU 7       120159.0          56416.0                6.778890e+09
# 8    SKU 9       120719.0          42351.0                5.112570e+09
# 5    SKU 6       131255.0          34867.0                4.576468e+09
# 2    SKU 3       106396.0          40218.0                4.279034e+09
# 10  SKU 11       112246.0          35468.0                3.981141e+09
# 1    SKU 2       108196.0          35621.0                3.854050e+09
# 11  SKU 12       109188.0          24690.0                2.695852e+09
# 0    SKU 1       100571.0          26478.0                2.662919e+09
#
#     Costos Acumuludos  Porcentaje de costos acumulados Class
# 3        8.492634e+09                         0.131360     A
# 7        1.639846e+10                         0.253644     A
# 4        2.364673e+10                         0.365756     A
# 9        3.071068e+10                         0.475018     A
# 6        3.748957e+10                         0.579871     B
# 8        4.260214e+10                         0.658949     B
# 5        4.717860e+10                         0.729736     B
# 2        5.145764e+10                         0.795922     B
# 10       5.543878e+10                         0.857501     B
# 1        5.929283e+10                         0.917113     C
# 11       6.198868e+10                         0.958811     C
# 0        6.465160e+10                         1.000000     C

# %% [markdown]
# ## Clasificación ABC ventas (Precio x Demanda)

# %%
data
# Out:
#               Tipo   Familias    SKUS  Cargo de Mantener una unidad en un año  \
# 0   compra y venta  Familia 1   SKU 1                                    0.18
# 1   compra y venta        NaN   SKU 2                                    0.18
# 2   compra y venta        NaN   SKU 3                                    0.18
# 3    Manufacturado  Familia 2   SKU 4                                    0.26
# 4    Manufacturado        NaN   SKU 5                                    0.26
# 5    Manufacturado        NaN   SKU 6                                    0.26
# 6   compra y venta  Familia 3   SKU 7                                    0.20
# 7   compra y venta        NaN   SKU 8                                    0.20
# 8   compra y venta        NaN   SKU 9                                    0.20
# 9    Manufacturado  Familia 4  SKU 10                                    0.25
# 10   Manufacturado        NaN  SKU 11                                    0.25
# 11   Manufacturado        NaN  SKU 12                                    0.25
#
#    Rentabilidad  Total Demanda  Promedio semana  Desv. Estándar        Cv  \
# 0          0.18       100571.0      1117.455556      548.693672  0.491021
# 1          0.25       108196.0      1202.177778      598.309990  0.497688
# 2          0.22       106396.0      1182.177778      603.645267  0.510621
# 3          0.26       131526.0      1461.400000      274.140774  0.187588
# 4          0.25       128338.0      1425.977778      253.785275  0.177973
# 5           0.3       131255.0      1458.388889      281.232548  0.192838
# 6          0.15       120159.0      1335.100000      456.989761  0.342289
# 7          0.21       123184.0      1368.711111      501.595393  0.366473
# 8          0.25       120719.0      1341.322222      413.133431  0.308005
# 9          0.28       113177.0      1257.522222      434.914669  0.345850
# 10          0.3       112246.0      1247.177778      442.127151  0.354502
# 11         0.22       109188.0      1213.200000      414.435428  0.341605
#
#     Costo unitario   Costo Ordenar  Tasa Pdn (unid por semana)
# 0           26478.0      3415860.0                         NaN
# 1           35621.0      5124610.0                         NaN
# 2           40218.0      2471600.0                         NaN
# 3           64570.0      3451200.0                      1800.0
# 4           56478.0      4023600.0                      2000.0
# 5           34867.0      3845650.0                      1700.0
# 6           56416.0      6451870.0                         NaN
# 7           64179.0      4781900.0                         NaN
# 8           42351.0      2345640.0                         NaN
# 9           62415.0      7845000.0                      1500.0
# 10          35468.0      4567180.0                      2200.0
# 11          24690.0      3654130.0                      2500.0

# %%
dataSub = data[["SKUS",'Total Demanda','Costo unitario ',"Rentabilidad" ]]

# %%
dataSub["Precio"] =  data['Costo unitario '] * data["Rentabilidad"] +  data['Costo unitario ']
# Out:
# <ipython-input-179-1a4cc0e08882>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSub["Precio"] =  data['Costo unitario '] * data["Rentabilidad"] +  data['Costo unitario ']

# %%
dataSub = dataSub.sort_values(by="Precio", ascending=False)

# %%
totalPrecios = dataSub["Precio"].sum()
totalPrecios
# Out:
# 673714.1900000002

# %%
dataSub["Precios Acumulados"] = dataSub["Precio"].cumsum()

# %%
dataSub
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad    Precio  \
# 3    SKU 4       131526.0          64570.0         0.26   81358.2
# 9   SKU 10       113177.0          62415.0         0.28   79891.2
# 7    SKU 8       123184.0          64179.0         0.21  77656.59
# 4    SKU 5       128338.0          56478.0         0.25   70597.5
# 6    SKU 7       120159.0          56416.0         0.15   64878.4
# 8    SKU 9       120719.0          42351.0         0.25  52938.75
# 2    SKU 3       106396.0          40218.0         0.22  49065.96
# 10  SKU 11       112246.0          35468.0          0.3   46108.4
# 5    SKU 6       131255.0          34867.0          0.3   45327.1
# 1    SKU 2       108196.0          35621.0         0.25  44526.25
# 0    SKU 1       100571.0          26478.0         0.18  31244.04
# 11  SKU 12       109188.0          24690.0         0.22   30121.8
#
#    Precios Acumulados
# 3             81358.2
# 9            161249.4
# 7           238905.99
# 4           309503.49
# 6           374381.89
# 8           427320.64
# 2            476386.6
# 10           522495.0
# 5            567822.1
# 1           612348.35
# 0           643592.39
# 11          673714.19

# %%
# Calcular el porcentaje de contribución de cada SKU al total de costo
dataSub['Porcentaje Contribución'] = (dataSub['Precios Acumulados'] / totalPrecios )

# %%
dataSub = dataSub.sort_values(by='Precios Acumulados', ascending=True)
dataSub
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad    Precio  \
# 3    SKU 4       131526.0          64570.0         0.26   81358.2
# 9   SKU 10       113177.0          62415.0         0.28   79891.2
# 7    SKU 8       123184.0          64179.0         0.21  77656.59
# 4    SKU 5       128338.0          56478.0         0.25   70597.5
# 6    SKU 7       120159.0          56416.0         0.15   64878.4
# 8    SKU 9       120719.0          42351.0         0.25  52938.75
# 2    SKU 3       106396.0          40218.0         0.22  49065.96
# 10  SKU 11       112246.0          35468.0          0.3   46108.4
# 5    SKU 6       131255.0          34867.0          0.3   45327.1
# 1    SKU 2       108196.0          35621.0         0.25  44526.25
# 0    SKU 1       100571.0          26478.0         0.18  31244.04
# 11  SKU 12       109188.0          24690.0         0.22   30121.8
#
#    Precios Acumulados Porcentaje Contribución
# 3             81358.2                0.120761
# 9            161249.4                0.239344
# 7           238905.99                 0.35461
# 4           309503.49                0.459399
# 6           374381.89                0.555698
# 8           427320.64                0.634276
# 2            476386.6                0.707105
# 10           522495.0                0.775544
# 5            567822.1                0.842823
# 1           612348.35                0.908914
# 0           643592.39                 0.95529
# 11          673714.19                     1.0

# %%
dataSub['Class'] = dataSub['Porcentaje Contribución'].apply(ABC)

# %%
dataSub
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad    Precio  \
# 3    SKU 4       131526.0          64570.0         0.26   81358.2
# 9   SKU 10       113177.0          62415.0         0.28   79891.2
# 7    SKU 8       123184.0          64179.0         0.21  77656.59
# 4    SKU 5       128338.0          56478.0         0.25   70597.5
# 6    SKU 7       120159.0          56416.0         0.15   64878.4
# 8    SKU 9       120719.0          42351.0         0.25  52938.75
# 2    SKU 3       106396.0          40218.0         0.22  49065.96
# 10  SKU 11       112246.0          35468.0          0.3   46108.4
# 5    SKU 6       131255.0          34867.0          0.3   45327.1
# 1    SKU 2       108196.0          35621.0         0.25  44526.25
# 0    SKU 1       100571.0          26478.0         0.18  31244.04
# 11  SKU 12       109188.0          24690.0         0.22   30121.8
#
#    Precios Acumulados Porcentaje Contribución Class
# 3             81358.2                0.120761     A
# 9            161249.4                0.239344     A
# 7           238905.99                 0.35461     A
# 4           309503.49                0.459399     A
# 6           374381.89                0.555698     B
# 8           427320.64                0.634276     B
# 2            476386.6                0.707105     B
# 10           522495.0                0.775544     B
# 5            567822.1                0.842823     B
# 1           612348.35                0.908914     C
# 0           643592.39                 0.95529     C
# 11          673714.19                     1.0     C

# %% [markdown]
# ## Clasificación ABC margen (Ganancia x Demanda)

# %%
dataSub2 = data[["SKUS",'Total Demanda','Costo unitario ',"Rentabilidad" ]]

# %%
dataSub2["Margen total acumulado por sku"] =  data['Costo unitario '] * data["Rentabilidad"] * data['Total Demanda']
# Out:
# <ipython-input-189-ae5e82fb92d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSub2["Margen total acumulado por sku"] =  data['Costo unitario '] * data["Rentabilidad"] * data['Total Demanda']

# %%
totalMargen = dataSub2["Margen total acumulado por sku"].sum()
totalMargen
# Out:
# 15497852164.31

# %%
dataSub2 = dataSub2.sort_values(by="Margen total acumulado por sku", ascending=False)

# %%
dataSub2
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad  \
# 3    SKU 4       131526.0          64570.0         0.26
# 9   SKU 10       113177.0          62415.0         0.28
# 4    SKU 5       128338.0          56478.0         0.25
# 7    SKU 8       123184.0          64179.0         0.21
# 5    SKU 6       131255.0          34867.0          0.3
# 8    SKU 9       120719.0          42351.0         0.25
# 10  SKU 11       112246.0          35468.0          0.3
# 6    SKU 7       120159.0          56416.0         0.15
# 1    SKU 2       108196.0          35621.0         0.25
# 2    SKU 3       106396.0          40218.0         0.22
# 11  SKU 12       109188.0          24690.0         0.22
# 0    SKU 1       100571.0          26478.0         0.18
#
#    Margen total acumulado por sku
# 3                    2208084793.2
# 9                    1977903887.4
# 4                    1812068391.0
# 7                   1660223446.56
# 5                    1372940425.5
# 8                   1278142592.25
# 10                   1194342338.4
# 6                    1016833521.6
# 1                     963512429.0
# 2                    941387552.16
# 11                    593087378.4
# 0                    479325408.84

# %%
dataSub2["Margenes acumulados"] = dataSub2["Margen total acumulado por sku"].cumsum()

# %%
dataSub2
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad  \
# 3    SKU 4       131526.0          64570.0         0.26
# 9   SKU 10       113177.0          62415.0         0.28
# 4    SKU 5       128338.0          56478.0         0.25
# 7    SKU 8       123184.0          64179.0         0.21
# 5    SKU 6       131255.0          34867.0          0.3
# 8    SKU 9       120719.0          42351.0         0.25
# 10  SKU 11       112246.0          35468.0          0.3
# 6    SKU 7       120159.0          56416.0         0.15
# 1    SKU 2       108196.0          35621.0         0.25
# 2    SKU 3       106396.0          40218.0         0.22
# 11  SKU 12       109188.0          24690.0         0.22
# 0    SKU 1       100571.0          26478.0         0.18
#
#    Margen total acumulado por sku Margenes acumulados
# 3                    2208084793.2        2208084793.2
# 9                    1977903887.4        4185988680.6
# 4                    1812068391.0        5998057071.6
# 7                   1660223446.56       7658280518.16
# 5                    1372940425.5       9031220943.66
# 8                   1278142592.25      10309363535.91
# 10                   1194342338.4  11503705874.309999
# 6                    1016833521.6      12520539395.91
# 1                     963512429.0      13484051824.91
# 2                    941387552.16      14425439377.07
# 11                    593087378.4  15018526755.469999
# 0                    479325408.84  15497852164.309999

# %%
# Calcular el porcentaje de contribución de cada SKU al total de costo
dataSub2['Porcentaje Contribución'] = (dataSub2['Margenes acumulados'] / totalMargen )

# %%
dataSub2['Class'] = dataSub2['Porcentaje Contribución'].apply(ABC)

# %%
dataSub2
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad  \
# 3    SKU 4       131526.0          64570.0         0.26
# 9   SKU 10       113177.0          62415.0         0.28
# 4    SKU 5       128338.0          56478.0         0.25
# 7    SKU 8       123184.0          64179.0         0.21
# 5    SKU 6       131255.0          34867.0          0.3
# 8    SKU 9       120719.0          42351.0         0.25
# 10  SKU 11       112246.0          35468.0          0.3
# 6    SKU 7       120159.0          56416.0         0.15
# 1    SKU 2       108196.0          35621.0         0.25
# 2    SKU 3       106396.0          40218.0         0.22
# 11  SKU 12       109188.0          24690.0         0.22
# 0    SKU 1       100571.0          26478.0         0.18
#
#    Margen total acumulado por sku Margenes acumulados Porcentaje Contribución  \
# 3                    2208084793.2        2208084793.2                0.142477
# 9                    1977903887.4        4185988680.6                0.270101
# 4                    1812068391.0        5998057071.6                0.387025
# 7                   1660223446.56       7658280518.16                0.494151
# 5                    1372940425.5       9031220943.66                 0.58274
# 8                   1278142592.25      10309363535.91                0.665212
# 10                   1194342338.4  11503705874.309999                0.742277
# 6                    1016833521.6      12520539395.91                0.807889
# 1                     963512429.0      13484051824.91                0.870059
# 2                    941387552.16      14425439377.07                0.930802
# 11                    593087378.4  15018526755.469999                0.969071
# 0                    479325408.84  15497852164.309999                     1.0
#
#    Class
# 3      A
# 9      A
# 4      A
# 7      A
# 5      B
# 8      B
# 10     B
# 6      B
# 1      B
# 2      C
# 11     C
# 0      C

# %% [markdown]
# # Clasificación ABC Inventarios

# %% [markdown]
# ## Clasificación ABC Inventario x Demanda

# %% [markdown]
# ## Analisis comparativo

# %% [markdown]
# * Clasificación ABC - Ventas - Costos

# %%
dataSubset
# Out:
#       SKUS  Total Demanda  Costo unitario   Valor Total costos por sku  \
# 3    SKU 4       131526.0          64570.0                8.492634e+09
# 7    SKU 8       123184.0          64179.0                7.905826e+09
# 4    SKU 5       128338.0          56478.0                7.248274e+09
# 9   SKU 10       113177.0          62415.0                7.063942e+09
# 6    SKU 7       120159.0          56416.0                6.778890e+09
# 8    SKU 9       120719.0          42351.0                5.112570e+09
# 5    SKU 6       131255.0          34867.0                4.576468e+09
# 2    SKU 3       106396.0          40218.0                4.279034e+09
# 10  SKU 11       112246.0          35468.0                3.981141e+09
# 1    SKU 2       108196.0          35621.0                3.854050e+09
# 11  SKU 12       109188.0          24690.0                2.695852e+09
# 0    SKU 1       100571.0          26478.0                2.662919e+09
#
#     Costos Acumuludos  Porcentaje de costos acumulados Class
# 3        8.492634e+09                         0.131360     A
# 7        1.639846e+10                         0.253644     A
# 4        2.364673e+10                         0.365756     A
# 9        3.071068e+10                         0.475018     A
# 6        3.748957e+10                         0.579871     B
# 8        4.260214e+10                         0.658949     B
# 5        4.717860e+10                         0.729736     B
# 2        5.145764e+10                         0.795922     B
# 10       5.543878e+10                         0.857501     B
# 1        5.929283e+10                         0.917113     C
# 11       6.198868e+10                         0.958811     C
# 0        6.465160e+10                         1.000000     C

# %% [markdown]
# * Clasificación ABC - Ventas - Precios

# %%
dataSub
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad    Precio  \
# 3    SKU 4       131526.0          64570.0         0.26   81358.2
# 9   SKU 10       113177.0          62415.0         0.28   79891.2
# 7    SKU 8       123184.0          64179.0         0.21  77656.59
# 4    SKU 5       128338.0          56478.0         0.25   70597.5
# 6    SKU 7       120159.0          56416.0         0.15   64878.4
# 8    SKU 9       120719.0          42351.0         0.25  52938.75
# 2    SKU 3       106396.0          40218.0         0.22  49065.96
# 10  SKU 11       112246.0          35468.0          0.3   46108.4
# 5    SKU 6       131255.0          34867.0          0.3   45327.1
# 1    SKU 2       108196.0          35621.0         0.25  44526.25
# 0    SKU 1       100571.0          26478.0         0.18  31244.04
# 11  SKU 12       109188.0          24690.0         0.22   30121.8
#
#    Precios Acumulados Porcentaje Contribución Class
# 3             81358.2                0.120761     A
# 9            161249.4                0.239344     A
# 7           238905.99                 0.35461     A
# 4           309503.49                0.459399     A
# 6           374381.89                0.555698     B
# 8           427320.64                0.634276     B
# 2            476386.6                0.707105     B
# 10           522495.0                0.775544     B
# 5            567822.1                0.842823     B
# 1           612348.35                0.908914     C
# 0           643592.39                 0.95529     C
# 11          673714.19                     1.0     C

# %% [markdown]
# * Clasificación ABC - Ventas - Margen

# %%
dataSub2
# Out:
#       SKUS  Total Demanda  Costo unitario  Rentabilidad  \
# 3    SKU 4       131526.0          64570.0         0.26
# 9   SKU 10       113177.0          62415.0         0.28
# 4    SKU 5       128338.0          56478.0         0.25
# 7    SKU 8       123184.0          64179.0         0.21
# 5    SKU 6       131255.0          34867.0          0.3
# 8    SKU 9       120719.0          42351.0         0.25
# 10  SKU 11       112246.0          35468.0          0.3
# 6    SKU 7       120159.0          56416.0         0.15
# 1    SKU 2       108196.0          35621.0         0.25
# 2    SKU 3       106396.0          40218.0         0.22
# 11  SKU 12       109188.0          24690.0         0.22
# 0    SKU 1       100571.0          26478.0         0.18
#
#    Margen total acumulado por sku Margenes acumulados Porcentaje Contribución  \
# 3                    2208084793.2        2208084793.2                0.142477
# 9                    1977903887.4        4185988680.6                0.270101
# 4                    1812068391.0        5998057071.6                0.387025
# 7                   1660223446.56       7658280518.16                0.494151
# 5                    1372940425.5       9031220943.66                 0.58274
# 8                   1278142592.25      10309363535.91                0.665212
# 10                   1194342338.4  11503705874.309999                0.742277
# 6                    1016833521.6      12520539395.91                0.807889
# 1                     963512429.0      13484051824.91                0.870059
# 2                    941387552.16      14425439377.07                0.930802
# 11                    593087378.4  15018526755.469999                0.969071
# 0                    479325408.84  15497852164.309999                     1.0
#
#    Class
# 3      A
# 9      A
# 4      A
# 7      A
# 5      B
# 8      B
# 10     B
# 6      B
# 1      B
# 2      C
# 11     C
# 0      C

# %% [markdown]
# * Clasificación ABC - Inventarios -

# %% [markdown]
# * Analisis comparativo

# %%
df_clasificaciones = pd.DataFrame({
    'SKUS': range(1, 13),  # Filas de 1 a 12 SKUs
    'Costos': dataSubset.Class,
    'Precios': dataSub.Class,
    'Margen': dataSub2.Class
})

# %%
df_clasificaciones
# Out:
#     SKUS Costos Precios Margen
# 0      1      C       C      C
# 1      2      C       C      B
# 2      3      B       B      C
# 3      4      A       A      A
# 4      5      A       A      A
# 5      6      B       B      B
# 6      7      B       B      B
# 7      8      A       A      A
# 8      9      B       B      B
# 9     10      A       A      A
# 10    11      B       B      B
# 11    12      C       C      C

# %% [markdown]
# # Definir base de datos y parametros

# %%
DataFrameEOQ2 = data

data
# Out:
#               Tipo   Familias    SKUS  Cargo de Mantener una unidad en un año  \
# 0   compra y venta  Familia 1   SKU 1                                    0.18
# 1   compra y venta        NaN   SKU 2                                    0.18
# 2   compra y venta        NaN   SKU 3                                    0.18
# 3    Manufacturado  Familia 2   SKU 4                                    0.26
# 4    Manufacturado        NaN   SKU 5                                    0.26
# 5    Manufacturado        NaN   SKU 6                                    0.26
# 6   compra y venta  Familia 3   SKU 7                                    0.20
# 7   compra y venta        NaN   SKU 8                                    0.20
# 8   compra y venta        NaN   SKU 9                                    0.20
# 9    Manufacturado  Familia 4  SKU 10                                    0.25
# 10   Manufacturado        NaN  SKU 11                                    0.25
# 11   Manufacturado        NaN  SKU 12                                    0.25
#
#    Rentabilidad  Total Demanda  Promedio semana  Desv. Estándar        Cv  \
# 0          0.18       100571.0      1117.455556      548.693672  0.491021
# 1          0.25       108196.0      1202.177778      598.309990  0.497688
# 2          0.22       106396.0      1182.177778      603.645267  0.510621
# 3          0.26       131526.0      1461.400000      274.140774  0.187588
# 4          0.25       128338.0      1425.977778      253.785275  0.177973
# 5           0.3       131255.0      1458.388889      281.232548  0.192838
# 6          0.15       120159.0      1335.100000      456.989761  0.342289
# 7          0.21       123184.0      1368.711111      501.595393  0.366473
# 8          0.25       120719.0      1341.322222      413.133431  0.308005
# 9          0.28       113177.0      1257.522222      434.914669  0.345850
# 10          0.3       112246.0      1247.177778      442.127151  0.354502
# 11         0.22       109188.0      1213.200000      414.435428  0.341605
#
#     Costo unitario   Costo Ordenar  Tasa Pdn (unid por semana)
# 0           26478.0      3415860.0                         NaN
# 1           35621.0      5124610.0                         NaN
# 2           40218.0      2471600.0                         NaN
# 3           64570.0      3451200.0                      1800.0
# 4           56478.0      4023600.0                      2000.0
# 5           34867.0      3845650.0                      1700.0
# 6           56416.0      6451870.0                         NaN
# 7           64179.0      4781900.0                         NaN
# 8           42351.0      2345640.0                         NaN
# 9           62415.0      7845000.0                      1500.0
# 10          35468.0      4567180.0                      2200.0
# 11          24690.0      3654130.0                      2500.0

# %%
DataFrameEOQ1 = pd.read_excel("/content/drive/MyDrive/Operaciones I/Base de datos/Datos SKUS.xlsx")

DataFrameEOQ1
# Out:
#         SKU  Semana  Demanda  Inv Final  Pedido  Recibo
# 0      SKU1       1     1376       6475     NaN     NaN
# 1      SKU1       2     1284       5191     NaN     NaN
# 2      SKU1       3      983       4208  6000.0     NaN
# 3      SKU1       4     1740       2468     NaN     NaN
# 4      SKU1       5     1442       1026     NaN  6000.0
# ...     ...     ...      ...        ...     ...     ...
# 1075  SKU12      86      690      10872     NaN     NaN
# 1076  SKU12      87      675      10197     NaN     NaN
# 1077  SKU12      88      739       9458     NaN     NaN
# 1078  SKU12      89      499       8959     NaN     NaN
# 1079  SKU12      90      547       8412     NaN     NaN
#
# [1080 rows x 6 columns]

# %% [markdown]
# * Economic Order Quantity (EOQ)

# %%
#@title EOQ Formula
import math
def eoq (D, S, h):
  return math.sqrt((2 * D * S) /  (h))

# %% [markdown]
# * Economic Production Quantity (EPQ)

# %%
#@title EPQ Formula
import math
def epq(D, S, h, p):
    return math.sqrt(   (2 * D * S) / ((1 - (D / p)) * h)   )

# %%
#@title Calculate parameters

def calculate_Annual_Demand(sku):
  demanda_promedio = (DataFrameEOQ1[DataFrameEOQ1['SKU'].isin([sku])]["Demanda"].sum())/90 #Se saca el promedio de la demanda total (90 semanas)
  return demanda_promedio * 52 # y se multiplica por un año (52 semanas)

def fixed_Costs(sku):
  costo_por_ordenar = DataFrameEOQ2.loc[DataFrameEOQ2['SKUS'] == sku, "Costo Ordenar"].iloc[0]
  return costo_por_ordenar

def holding_Costs(sku):
    costo_por_mantener = DataFrameEOQ2.loc[DataFrameEOQ2['SKUS'] == sku, "Cargo de Mantener una unidad en un año"].iloc[0]
    costo_unitario = unit_Cost(sku)
    return costo_por_mantener * costo_unitario # Se multiplica el costo por mantener un sku especifico por su costo unitario

def unit_Cost(sku):
    return DataFrameEOQ2.loc[DataFrameEOQ2['SKUS'] == sku, "Costo unitario "].iloc[0]

def productionRate(sku):
  return DataFrameEOQ2.loc[DataFrameEOQ2['SKUS'] == sku, "Tasa Pdn (unid por semana)"].iloc[0]*52

# %% [markdown]
# # Lot Sizing for a Single Product (Economic Order Quantity) (EOQ)

# %% [markdown]
# **1. Calcular el EOQ Del SKU 1, para 1 año (52 semanas)**

# %%
D = calculate_Annual_Demand("SKU1")

S = fixed_Costs("SKU 1")

h = holding_Costs("SKU 1")

c = unit_Cost("SKU 1")

# %%
print("Demanda total: ", D ,

      " Costo por ordenar: ", S ,

      " Costos inventario: ", h ,

      " Costo unitario: ", c)
# Out:
# Demanda total:  58107.688888888886  Costo por ordenar:  3415860.0  Costos inventario:  4766.04  Costo unitario:  26478.0

# %%
print(" EOQ : ", eoq(D,S,h))
# Out:
#  EOQ :  9126.473330380311

# %% [markdown]
# ***2. Calcular el EOQ Del SKU 2, para 1 año (52 semanas)***

# %%
D2 = calculate_Annual_Demand("SKU2")

S2 = fixed_Costs("SKU 2")

h2 = holding_Costs("SKU 2")

c2 = unit_Cost("SKU 2")

# %%
print("Demanda total: ", D2 ,

      " Costo por ordenar: ", S2 ,

      " Costos inventario: ", h2 ,

      " Costo unitario: ", c2)
# Out:
# Demanda total:  62513.24444444444  Costo por ordenar:  5124610.0  Costos inventario:  6411.78  Costo unitario:  35621.0

# %%
print(" EOQ : ", eoq(D2,S2,h2))
# Out:
#  EOQ :  9996.365365948726

# %% [markdown]
# ***3. Calcular el EOQ Del SKU 3, para 1 año (52 semanas)***

# %%
D3 = calculate_Annual_Demand("SKU3")

S3 = fixed_Costs("SKU 3")

h3 = holding_Costs("SKU 3")

c3 = unit_Cost("SKU 3")

# %%
print("Demanda total: ", D3 ,

      " Costo por ordenar: ", S3,

      " Costos inventario: ", h3 ,

      " Costo unitario: ", c3)
# Out:
# Demanda total:  61473.24444444444  Costo por ordenar:  2471600.0  Costos inventario:  7239.24  Costo unitario:  40218.0

# %%
print(" EOQ : ", eoq(D3,S3,h3))
# Out:
#  EOQ :  6478.890965127125

# %% [markdown]
# ***7. Calcular el EOQ Del SKU 7, para 1 año (52 semanas)***

# %%
D7 = calculate_Annual_Demand("SKU7")

S7 = fixed_Costs("SKU 7")

h7 = holding_Costs("SKU 7")

c7 = unit_Cost("SKU 7")

# %%
print("Demanda total: ", D7 ,

      " Costo por ordenar: ", S7,

      " Costos inventario: ", h7 ,

      " Costo unitario: ", c7)
# Out:
# Demanda total:  69425.2  Costo por ordenar:  6451870.0  Costos inventario:  11283.2  Costo unitario:  56416.0

# %%
print(" EOQ : ", eoq(D7,S7,h7))
# Out:
#  EOQ :  8910.46212502362

# %% [markdown]
# ***8. Calcular el EOQ Del SKU 3, para 1 año (52 semanas)***

# %%
D8 = calculate_Annual_Demand("SKU8")

S8 = fixed_Costs("SKU 8")

h8 = holding_Costs("SKU 8")

c8 = unit_Cost("SKU 8")

# %%
print("Demanda total: ", D8 ,

      " Costo por ordenar: ", S8,

      " Costos inventario: ", h8 ,

      " Costo unitario: ", c8)
# Out:
# Demanda total:  71172.97777777778  Costo por ordenar:  4781900.0  Costos inventario:  12835.800000000001  Costo unitario:  64179.0

# %%
print(" EOQ : ", eoq(D8,S8,h8))
# Out:
#  EOQ :  7282.178837036799

# %% [markdown]
# ***9. Calcular el EOQ Del SKU 3, para 1 año (52 semanas)***

# %%
D9 = calculate_Annual_Demand("SKU9")

S9 = fixed_Costs("SKU 9")

h9 = holding_Costs("SKU 9")

c9 = unit_Cost("SKU 9")

# %%
print("Demanda total: ", D9 ,

      " Costo por ordenar: ", S9,

      " Costos inventario: ", h9 ,

      " Costo unitario: ", c9)
# Out:
# Demanda total:  69748.75555555556  Costo por ordenar:  2345640.0  Costos inventario:  8470.2  Costo unitario:  42351.0

# %%
print(" EOQ : ", eoq(D9,S9,h9))
# Out:
#  EOQ :  6215.371277520861

# %% [markdown]
# # Lot Sizing for a Single Product (Economic production Quantity) (EPQ)

# %% [markdown]
# **1. Calcular el EPQ Del SKU 4, para 1 año (52 semanas)**

# %%
D4 = calculate_Annual_Demand("SKU4")

S4 = fixed_Costs("SKU 4")

h4 = holding_Costs("SKU 4")

c4 = unit_Cost("SKU 4")

p4 = productionRate("SKU 4")

# %%
print("Demanda total: ", D4 ,

      " Costo por ordenar: ", S4 ,

      " Costos inventario: ", h4 ,

      " Costo unitario: ", c4 ,

      " Tasa de producción: ", p4)
# Out:
# Demanda total:  75992.8  Costo por ordenar:  3451200.0  Costos inventario:  16788.2  Costo unitario:  64570.0  Tasa de producción:  93600.0

# %%
print(" EPQ : ", epq(D4,S4,h4,p4))
# Out:
#  EPQ :  12887.74675285781

# %% [markdown]
# **2. Calcular el EPQ Del SKU 5, para 1 año (52 semanas)**

# %%
D5 = calculate_Annual_Demand("SKU5")

S5 = fixed_Costs("SKU 5")

h5 = holding_Costs("SKU 5")

c5 = unit_Cost("SKU 5")

p5 = productionRate("SKU 5")

# %%
print("Demanda total: ", D5 ,

      " Costo por ordenar: ", S5 ,

      " Costos inventario: ", h5 ,

      " Costo unitario: ", c5,

      " Tasa de producción: ", p5)
# Out:
# Demanda total:  74150.84444444445  Costo por ordenar:  4023600.0  Costos inventario:  14684.28  Costo unitario:  56478.0  Tasa de producción:  104000.0

# %%
print(" EPQ : ", epq(D5,S5,h5,p5))
# Out:
#  EPQ :  11898.84383385189

# %% [markdown]
# **3. Calcular el EPQ Del SKU 6, para 1 año (52 semanas)**

# %%
D6 = calculate_Annual_Demand("SKU6")

S6 = fixed_Costs("SKU 6")

h6 = holding_Costs("SKU 6")

c6 = unit_Cost("SKU 6")

p6 = productionRate("SKU 6")

# %%
print("Demanda total: ", D6,

      " Costo por ordenar: ", S6,

      " Costos inventario: ", h6,

      " Costo unitario: ", c6,

      " Tasa de producción: ", p6)
# Out:
# Demanda total:  75836.22222222222  Costo por ordenar:  3845650.0  Costos inventario:  9065.42  Costo unitario:  34867.0  Tasa de producción:  88400.0

# %%
print(" EPQ : ", epq(D6,S6,h6,p6))
# Out:
#  EPQ :  21276.993724993536

# %% [markdown]
# **4. Calcular el EOQ Del SKU 10, para 1 año (52 semanas)**

# %%
D10 = calculate_Annual_Demand("SKU10")

S10 = fixed_Costs("SKU 10")

h10 = holding_Costs("SKU 10")

c10 = unit_Cost("SKU 10")

p10 = productionRate("SKU 10")

# %%
print("Demanda total: ", D10,

      " Costo por ordenar: ", S10,

      " Costos inventario: ", h10,

      " Costo unitario: ", c10,

      " Tasa de producción: ", p10)
# Out:
# Demanda total:  65391.15555555555  Costo por ordenar:  7845000.0  Costos inventario:  15603.75  Costo unitario:  62415.0  Tasa de producción:  78000.0

# %%
print(" EPQ : ", epq(D10,S10,h10,p10))
# Out:
#  EPQ :  20168.15377247514

# %% [markdown]
# **5. Calcular el EOQ Del SKU 11, para 1 año (52 semanas)**

# %%
D11 = calculate_Annual_Demand("SKU11")

S11 = fixed_Costs("SKU 11")

h11 = holding_Costs("SKU 11")

c11 = unit_Cost("SKU 11")

p11 = productionRate("SKU 11")

# %%
print("Demanda total: ", D11,

      " Costo por ordenar: ", S11,

      " Costos inventario: ", h11,

      " Costo unitario: ", c11,

      " Tasa de producción: ", p11)
# Out:
# Demanda total:  64853.24444444444  Costo por ordenar:  4567180.0  Costos inventario:  8867.0  Costo unitario:  35468.0  Tasa de producción:  114400.0

# %%
print(" EPQ : ", epq(D11,S11,h11,p11))
# Out:
#  EPQ :  12420.010505833696

# %% [markdown]
# **6. Calcular el EOQ Del SKU 12, para 1 año (52 semanas)**

# %%
D12 = calculate_Annual_Demand("SKU12")

S12 = fixed_Costs("SKU 12")

h12 = holding_Costs("SKU 12")

c12 = unit_Cost("SKU 12")

p12 = productionRate("SKU 12")

# %%
print("Demanda total: ", D12,

      " Costo por ordenar: ", S12,

      " Costos inventario: ", h12,

      " Costo unitario: ", c12,

      " Tasa de producción: ", p12)
# Out:
# Demanda total:  63086.4  Costo por ordenar:  3654130.0  Costos inventario:  6172.5  Costo unitario:  24690.0  Tasa de producción:  130000.0

# %%
print(" EPQ : ", epq(D12,S12,h12,p12))
# Out:
#  EPQ :  12046.44206473357

# %% [markdown]
# # Hola
